# %% [markdown]
# <a href="https://colab.research.google.com/github/WisdomdeSagesse/Salah-24-25-PL-Shot-Analysis/blob/main/DataExtraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install understatapi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.2/397.2 kB 7.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.5/147.5 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.1/138.1 kB 13.3 MB/s eta 0:00:00
# ...
#   Created wheel for understatapi: filename=understatapi-0.6.1-py3-none-any.whl size=15012 sha256=8581011cc84252601da1325542f1dbf18a879c50618b3118fccf13108b5c3414
#   Stored in directory: /root/.cache/pip/wheels/e6/68/25/f4615a050ec1ecf2d52cb4b0068c9823da3878c252aee71ecf
# ...

# %%
from understatapi import UnderstatClient

understat = UnderstatClient()
# get data for every player playing in the Premier League in 2019/20
league_player_data = understat.league(league="EPL").get_player_data(season="2024")
print(league_player_data)
# Out:
# [{'id': '1250', 'player_name': 'Mohamed Salah', 'games': '38', 'time': '3392', 'goals': '29', 'xG': '27.70626749098301', 'assists': '18', 'xA': '15.858334187418222', 'shots': '130', 'key_passes': '89', 'yellow_cards': '1', 'red_cards': '0', 'position': 'F M', 'team_title': 'Liverpool', 'npg': '20', 'npxG': '20.855747912079096', 'xGChain': '48.53588879853487', 'xGBuildup': '16.20675839856267'}, {'id': '5232', 'player_name': 'Alexander Isak', 'games': '34', 'time': '2822', 'goals': '23', 'xG': '22.356988068670034', 'assists': '6', 'xA': '5.44870379474014', 'shots': '99', 'key_passes': '42', 'yellow_cards': '1', 'red_cards': '0', 'position': 'F', 'team_title': 'Newcastle United', 'npg': '19', 'npxG': '19.312312599271536', 'xGChain': '26.209551103413105', 'xGBuildup': '3.579237926751375'}, {'id': '8260', 'player_name': 'Erling Haaland', 'games': '31', 'time': '2749', 'goals': '22', 'xG': '23.95459282770753', 'assists': '3', 'xA': '3.5812273556366563', 'shots': '109', 'key_passes': '29', 
# ...

# %%
player_id, player_name = league_player_data[0]["id"], league_player_data[0]["player_name"]
# Get data for every shot this player has taken in a league match (for all seasons)
player_shot_data = understat.player(player=player_id).get_shot_data()
print(player_shot_data)
# Out:
# [{'id': '15217', 'minute': '92', 'result': 'MissedShots', 'X': '0.8230000305175781', 'Y': '0.36900001525878906', 'xG': '0.0623646005988121', 'player': 'Mohamed Salah', 'h_a': 'h', 'player_id': '1250', 'situation': 'OpenPlay', 'season': '2014', 'shotType': 'LeftFoot', 'match_id': '4720', 'h_team': 'Chelsea', 'a_team': 'Swansea', 'h_goals': '4', 'a_goals': '2', 'date': '2014-09-13 15:00:00', 'player_assisted': 'Eden Hazard', 'lastAction': 'Pass'}, {'id': '20034', 'minute': '84', 'result': 'SavedShot', 'X': '0.92', 'Y': '0.5320000076293945', 'xG': '0.4399380087852478', 'player': 'Mohamed Salah', 'h_a': 'a', 'player_id': '1250', 'situation': 'OpenPlay', 'season': '2014', 'shotType': 'LeftFoot', 'match_id': '4560', 'h_team': 'Tottenham', 'a_team': 'Chelsea', 'h_goals': '5', 'a_goals': '3', 'date': '2015-01-01 17:30:00', 'player_assisted': 'Eden Hazard', 'lastAction': 'Pass'}, {'id': '46908', 'minute': '87', 'result': 'BlockedShot', 'X': '0.8859999847412109', 'Y': '0.5659999847412109', 'xG
# ...

# %%
import pandas as pd
df = pd.json_normalize(player_shot_data)


df_24_season = df.loc[df['season'] == '2024']
df_24_season
# Out:
#           id minute       result                   X                    Y  \
# 1099  584693     46  BlockedShot   0.874000015258789  0.33799999237060546
# 1100  584700     64         Goal  0.9369999694824219   0.4490000152587891
# 1101  584702     70    SavedShot  0.8369999694824218   0.5629999923706055
# 1102  584707     93    SavedShot  0.9309999847412109  0.34700000762939454
# 1103  586849     20  MissedShots  0.8819999694824219   0.3139999961853027
# ...      ...    ...          ...                 ...                  ...
# 1224  635663     75  BlockedShot  0.9159999847412109  0.38299999237060545
# 1225  635664     77  MissedShots   0.914000015258789                0.325
# 1226  636394     49  BlockedShot  0.8809999847412109  0.40599998474121096
# 1227  636402     66  MissedShots  0.8580000305175781                0.575
# 1228  636406     83         Goal  0.9259999847412109   0.4879999923706055
#
#                         xG         player h_a player_id   situation season  \
# ...

# %%
df_24_season.to_csv("SalahShotStats.csv", encoding= 'utf-8', header=True)
